# %%
import pandas as pd
import seaborn as sns
df=pd.read_csv("car data.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.head(10)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# ...

# %%
df.Fuel_Type.value_counts()
# Out:
# Petrol    139
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64

# %%
#data cleaning
df['new_Selling_Price']=df['Selling_Price']*100000
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  new_Selling_Price
# 0      Dealer       Manual      0           335000.0
# 1      Dealer       Manual      0           475000.0
# 2      Dealer       Manual      0           725000.0
# 3      Dealer       Manual      0           285000.0
# 4      Dealer       Manual      0           460000.0

# %%
df['new_Present_Price']=df['Present_Price']*100000
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  new_Selling_Price  new_Present_Price
# 0      Dealer       Manual      0           335000.0           559000.0
# 1      Dealer       Manual      0           475000.0           954000.0
# 2      Dealer       Manual      0           725000.0           985000.0
# 3      Dealer       Manual      0           285000.0           415000.0
# 4      Dealer       Manual      0           460000.0           687000.0

# %%
from datetime import date
  
# creating the date object of today's date
todays_date = date.today()
print(todays_date)

df["Car_Age"]=todays_date.year-df['Year']
df.head()
# Out:
# 2023-08-16
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  new_Selling_Price  new_Present_Price  \
# 0      Dealer       Manual      0           335000.0           559000.0
# 1      Dealer       Manual      0           475000.0           954000.0
# 2      Dealer       Manual      0           725000.0           985000.0
# 3      Dealer       Manual      0           285000.0           415000.0
# 4      Dealer       Manual      0           460000.0           687000.0
#
#    Car_Age
# 0        9
# 1       10
# 2        6
# 3       12
# 4        9

# %%
#checking for null values
df.isnull().sum()
# Out:
# Car_Name             0
# Year                 0
# Selling_Price        0
# Present_Price        0
# Kms_Driven           0
# Fuel_Type            0
# Seller_Type          0
# Transmission         0
# Owner                0
# new_Selling_Price    0
# new_Present_Price    0
# Car_Age              0
# dtype: int64

# %%
df.drop(["Year","Selling_Price","Present_Price"],axis=1,inplace=True)
df.head()
# Out:
#   Car_Name  Kms_Driven Fuel_Type Seller_Type Transmission  Owner  \
# 0     ritz       27000    Petrol      Dealer       Manual      0
# 1      sx4       43000    Diesel      Dealer       Manual      0
# 2     ciaz        6900    Petrol      Dealer       Manual      0
# 3  wagon r        5200    Petrol      Dealer       Manual      0
# 4    swift       42450    Diesel      Dealer       Manual      0
#
#    new_Selling_Price  new_Present_Price  Car_Age
# 0           335000.0           559000.0        9
# 1           475000.0           954000.0       10
# 2           725000.0           985000.0        6
# 3           285000.0           415000.0       12
# 4           460000.0           687000.0        9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Car_Name           201 non-null    object
#  1   Kms_Driven         201 non-null    int64
#  2   Fuel_Type          201 non-null    object
#  3   Seller_Type        201 non-null    object
#  4   Transmission       201 non-null    object
#  5   Owner              201 non-null    int64
#  6   new_Selling_Price  201 non-null    float64
#  7   new_Present_Price  201 non-null    float64
#  8   Car_Age            201 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 14.3+ KB

# %%
df['Fuel_Type']=df['Fuel_Type'].astype('category')

# %%
sns.countplot(data=df,x='Fuel_Type')
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='count'>

# %%
sns.countplot(data=df,x='Fuel_Type',hue='Transmission')
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='count'>

# %%
sns.countplot(data=df,x='Transmission')
# Out:
# <Axes: xlabel='Transmission', ylabel='count'>

# %%
sns.histplot(df['new_Present_Price'],bins=5,kde=True)

# %%
sns.histplot(df['new_Present_Price'],bins=50,kde=True)
# Out:
# <Axes: xlabel='new_Present_Price', ylabel='Count'>

# %%
sns.boxplot(df['new_Present_Price'],orient='h')
# Out:
# <Axes: >

# %%
cor_mat=df.corr()
cor_mat
# Out:
#                    Kms_Driven     Owner  new_Selling_Price  new_Present_Price  \
# Kms_Driven           1.000000  0.197756          -0.101332           0.253505
# Owner                0.197756  1.000000          -0.083620           0.047002
# new_Selling_Price   -0.101332 -0.083620           1.000000           0.826635
# new_Present_Price    0.253505  0.047002           0.826635           1.000000
# Car_Age              0.705477  0.152243          -0.346141           0.060279
#
#                     Car_Age
# Kms_Driven         0.705477
# Owner              0.152243
# new_Selling_Price -0.346141
# new_Present_Price  0.060279
# Car_Age            1.000000

# %%
import seaborn as sns
sns.heatmap(cor_mat,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x=df['new_Selling_Price'],y=df['Car_Age'])
# Out:
# <Axes: xlabel='new_Selling_Price', ylabel='Car_Age'>

# %%
sns.scatterplot(x=df['new_Selling_Price'],y=df['Car_Age'],hue=df['Transmission'])
# Out:
# <Axes: xlabel='new_Selling_Price', ylabel='Car_Age'>

# %%
sns.pairplot(df)
